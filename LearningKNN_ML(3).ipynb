# %% [markdown]
# <a href="https://colab.research.google.com/github/wayaadhyasta/LearningSchool_MeachineLearning-3-/blob/main/LearningKNN_ML(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dt = pd.read_csv('/content/drive/MyDrive/Data Intelligent Irrigation System.csv')
dt
# Out:
#        crop  moisture  temp  pump
# 0    cotton       638    16     1
# 1    cotton       522    18     1
# 2    cotton       741    22     1
# 3    cotton       798    32     1
# 4    cotton       690    28     1
# ..      ...       ...   ...   ...
# 195  cotton       941    13     1
# 196  cotton       902    45     1
# 197  cotton       894    42     1
# 198  cotton      1022    45     1
# 199  cotton       979    10     1
#
# [200 rows x 4 columns]

# %%
dt.head()
# Out:
#      crop  moisture  temp  pump
# 0  cotton       638    16     1
# 1  cotton       522    18     1
# 2  cotton       741    22     1
# 3  cotton       798    32     1
# 4  cotton       690    28     1

# %%
dt.tail()
# Out:
#        crop  moisture  temp  pump
# 195  cotton       941    13     1
# 196  cotton       902    45     1
# 197  cotton       894    42     1
# 198  cotton      1022    45     1
# 199  cotton       979    10     1

# %%
x = dt.iloc[:, [1,2]].values
y = dt.iloc[:, 3].values

# %% [markdown]
# variabel x = memuat atribute
# variabel y = memuat label/target
# [] =mengambil semua baris
# [1,2] dan [-1] = mengambil kolom atau index tertentu

# %%
from sklearn.model_selection import train_test_split # Corrected import statement
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.4, random_state = 0)

# %%
print(x_train)
# Out:
# [[ 974   28]
#  [ 824   37]
#  [   4   42]
#  [ 941   13]
#  [ 482   27]
#  [ 659   29]
#  [ 741   22]
#  [ 788   12]
#  [  87   12]
#  [ 894   42]
#  [ 749   38]
#  [ 671   23]
#  [ 914   35]
#  [ 611   12]
#  [ 902   45]
#  [1005   43]
#  [1010   10]
#  [ 354   20]
#  [ 817   18]
#  [ 306   25]
#  [ 865   17]
#  [ 986   36]
#  [ 775   40]
#  [ 638   16]
#  [ 830   44]
#  [ 208   39]
#  [ 843   41]
#  [ 641   35]
#  [1001   36]
#  [ 675   39]
#  [ 509   19]
#  [ 533   42]
#  [ 740   31]
#  [ 737   34]
#  [ 586   33]
#  [ 923   10]
#  [ 813   15]
#  [ 917   33]
#  [ 302   23]
#  [ 635   36]
#  [ 716   25]
#  [ 683   39]
#  [ 493   18]
#  [ 639   14]
#  [  89   42]
#  [ 539   26]
#  [ 798   32]
#  [  81   20]
#  [ 998   28]
#  [1022   45]
#  [ 578   12]
#  [ 792   15]
#  [ 579   45]
#  [ 161   18]
#  [1020   27]
#  [ 969   39]
#  [ 933   42]
#  [ 722   26]
#  [ 979   10]
#  [ 758   34]
#  [ 401   17]
#  [ 434   19]
#  [ 796   21]
#  [ 818   15]
#  [ 676   30]
#  [ 522   18]
#  [ 271   33]
#  [ 853   29]
#  [ 700   38]
#  [ 421   39]
#  [ 304   43]
#  [ 896   42]
#  [ 828   41]
#  [ 573   13]
#  [ 256   40]
#  [ 612   31]
#  [ 889   39]
#  [ 462   32]
#  [ 670   22]
#  [ 806   28]
#  [ 184   29]
#  [ 938   14]
#  [ 546   32]
#  [ 950   13]
#  [ 245   43]
#  [ 947   41]
#  [ 759   10]
#  [ 107   31]
#  [ 999   30]
#  [  52   44]
#  [ 681   31]
#  [ 733   26]
#  [ 768   17]
#  [ 760   18]
#  [ 429   17]
#  [ 149   24]
#  [1015   35]
#  [ 769   13]
#  [ 595   30]
#  [ 833   13]
#  [ 966   16]
#  [ 766   39]
#  [ 858   19]
#  [ 857   20]
#  [1021   22]
#  [ 812   38]
#  [ 503   44]
#  [  36   16]
#  [ 624   15]
#  [ 682   40]
#  [ 757   43]
#  [ 665   32]
#  [ 525   33]
#  [ 723   11]
#  [ 487   16]
#  [ 773   20]
#  [ 968   17]
#  [ 158   17]
#  [ 839   29]
#  [ 881   26]]

# %%
print(x_test)
# Out:
# [[ 633   23]
#  [ 873   44]
#  [ 177   12]
#  [ 588   18]
#  [ 859   20]
#  [ 878   29]
#  [ 558   23]
#  [ 143   43]
#  [ 507   45]
#  [ 981   36]
#  [ 729   41]
#  [ 293   25]
#  [ 893   39]
#  [ 876   40]
#  [ 697   25]
#  [ 673   35]
#  [ 803   21]
#  [  75   37]
#  [ 687   11]
#  [ 574   32]
#  [ 883   40]
#  [ 206   37]
#  [ 748   27]
#  [ 920   10]
#  [ 513   27]
#  [  26   23]
#  [ 937   28]
#  [1009   21]
#  [ 124   40]
#  [ 537   44]
#  [ 724   11]
#  [ 632   14]
#  [ 861   33]
#  [ 162   29]
#  [ 636   24]
#  [ 918   19]
#  [ 466   41]
#  [ 690   28]
#  [ 734   16]
#  [ 379   23]
#  [ 141   43]
#  [ 739   14]
#  [ 808   29]
#  [ 394   27]
#  [ 930   18]
#  [ 629   41]
#  [ 642   45]
#  [ 623   32]
#  [ 435   10]
#  [  21   37]
#  [ 637   29]
#  [ 175   15]
#  [ 888   44]
#  [ 837   30]
#  [  74   20]
#  [ 736   44]
#  [ 661   35]
#  [ 926   18]
#  [ 698   45]
#  [ 535   17]
#  [ 209   43]
#  [ 553   35]
#  [ 872   10]
#  [ 783   18]
#  [1019   37]
#  [ 795   15]
#  [ 580   14]
#  [ 922   23]
#  [ 663   24]
#  [ 699   22]
#  [ 178   39]
#  [ 850   16]
#  [  72   13]
#  [  76   35]
#  [  59   20]
#  [ 545   29]
#  [ 168   10]
#  [ 703   45]
#  [ 714   14]
#  [  39   38]]

# %% [markdown]
# Scalling Data
# bedanaya min max sm standar s-score adalah min max dipakai saat jumlah nilai dalam data itu rentang ny tidak jauh banyak, kalau s-score itu untuk nilai data yg rentang ny jauh

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3) # Corrected argument name to n_neighbors
knn.fit(x_train, y_train)

y_predict = knn.predict(x_test)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)
print(cm)
# Out:
# [[21  2]
#  [ 1 56]]

# %%
# Cek Akurasi
from sklearn.metrics import classification_report
akurasi = classification_report(y_test, y_predict)
print(akurasi)

from sklearn.metrics import accuracy_score
akurasi = accuracy_score(y_test, y_predict)
print('Tingkat Akurasi Adalah: %d persen'%(akurasi*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        23
#            1       0.97      0.98      0.97        57
#
#     accuracy                           0.96        80
#    macro avg       0.96      0.95      0.95        80
# weighted avg       0.96      0.96      0.96        80
#
# Tingkat Akurasi Adalah: 96 persen

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
x1, x2 = np.meshgrid.start[=x_set[:,0].min()] - 1, stop=x_set[:,0]

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train

x1, x2 = np.meshgrid(
    np.arange(start=x_set[:,0].min() - 1, stop=x_set[1,0].max() + 1, step=0.01),
    np.arange(start=x_set[:,1].min() - 1, stop=x_set[1,1].max() + 1, step=0.01)
    )

plt.contourf(
    x1, x2, knn.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
    alpha=0.75, cmap=ListedColormap(('red', 'blue'))
)

for i, j in enumerate(np.unique(y_set)):
  plt.scatter(
      x_set[y_set == j, 0], x_set[y_set == j, 1],
      color=ListedColormap(('red', 'blue'))(i), label=j
  )

plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
plt.xlabel('Fitur 1 (Setelah Standarisasi)')
plt.ylabel('Fitur 2 (Setelah Standarisasi)')
plt.legend()
plt.title('Decision Boundary dengan KNN (Sandarization)')
plt.show()
